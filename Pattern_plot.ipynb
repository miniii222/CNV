# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### K100

# %%
BC_100 = pd.read_csv('BC_32ea_k100_cyto.csv')
Normal_100 = pd.read_csv('Normal_21ea_k100_cyto.csv')
PC_100 = pd.read_csv('PC_20ea_k100_cyto.csv')
RC_100 = pd.read_csv('RC_20ea_k100_cyto.csv')

# %%
BC_100['cancer'] = 'BC'
Normal_100['cancer'] = 'normal'
PC_100['cancer'] = 'PC'
RC_100['cancer'] = "RC"

K100 = pd.concat([BC_100,Normal_100,PC_100,RC_100], axis = 0)
K100.drop(['<NA>'], axis = 1, inplace = True)

# %%
K100.reset_index(inplace = True)
K100.drop(['index','Unnamed: 0'],inplace = True, axis = 1)

# %%
K100.head()
# Out:
#      id  cyto.10p11.1  cyto.10p11.21  cyto.10p11.22  cyto.10p11.23  \
# 0  B001      0.181000      -0.019967       0.044536      -0.026000
# 1  B002      0.127000       0.010733       0.031250       0.048600
# 2  B003      0.004000       0.007567       0.024964       0.081200
# 3  B004      0.135667       0.061467      -0.061286      -0.071733
# 4  B006     -0.251000      -0.134700      -0.175750      -0.165800
#
#    cyto.10p12.1  cyto.10p12.2  cyto.10p12.31  cyto.10p12.32  cyto.10p12.33  \
# 0      0.018065       0.00490       0.048000          0.084      -0.042857
# 1      0.084413       0.05160       0.092889          0.102      -0.012857
# 2     -0.011391       0.03605      -0.050194         -0.093      -0.059857
# 3      0.070522       0.06270       0.020556         -0.002       0.050857
# 4     -0.112522      -0.06670      -0.127972          0.026      -0.198429
#
#     ...    cyto.9q32  cyto.9q33.1  cyto.9q33.2  cyto.9q33.3  cyto.9q34.11  \
# ...

# %%
K100.iloc[:31,765].value_counts()
# Out:
# BC    31
# Name: cancer, dtype: int64

# %%
K100.iloc[32:53,765].value_counts()
# Out:
# normal    21
# Name: cancer, dtype: int64

# %%
K100.iloc[53:73,765].value_counts()
# Out:
# PC    20
# Name: cancer, dtype: int64

# %%
BC_100.describe()
# Out:
#        Unnamed: 0  cyto.10p11.1  cyto.10p11.21  cyto.10p11.22  cyto.10p11.23  \
# count   32.000000     32.000000      32.000000      32.000000      32.000000
# mean    16.500000     -0.023031       0.011286       0.030946       0.009523
# std      9.380832      0.218580       0.131569       0.115801       0.110600
# min      1.000000     -0.518000      -0.233633      -0.175750      -0.222600
# 25%      8.750000     -0.130833      -0.039492      -0.000402      -0.051350
# 50%     16.500000     -0.039333       0.005117       0.021750       0.007533
# 75%     24.250000      0.100750       0.036758       0.044991       0.049017
# max     32.000000      0.752333       0.552800       0.538179       0.305533
#
#        cyto.10p12.1  cyto.10p12.2  cyto.10p12.31  cyto.10p12.32  \
# count     32.000000     32.000000      32.000000      32.000000
# mean       0.029260      0.033783       0.036593       0.064625
# std        0.087347      0.108695       0.125173       0.256492
# ...

# %%
RC_100.describe()
# Out:
#        Unnamed: 0  cyto.10p11.1  cyto.10p11.21  cyto.10p11.22  cyto.10p11.23  \
# count   21.000000     18.000000      18.000000      21.000000      18.000000
# mean    11.000000      0.106019       0.111346     -25.043430       0.129841
# std      6.204837      0.339468       0.359183     116.595136       0.418884
# min      1.000000     -0.222000      -0.196567    -533.888000      -0.080133
# 25%      6.000000     -0.074250      -0.030008       0.014714      -0.046933
# 50%     11.000000      0.018000       0.017800       0.043357       0.004733
# 75%     16.000000      0.055167       0.032100       0.069607       0.042067
# max     21.000000      1.000000       1.166667       4.441000       1.500000
#
#        cyto.10p12.1  cyto.10p12.2  cyto.10p12.31  cyto.10p12.32  \
# count     21.000000     21.000000      21.000000      18.000000
# mean      -3.731343      0.463900     -25.005939       0.144833
# std       19.391819      1.209047     116.606264       0.340895
# ...

# %%
PC_100.describe()
# Out:
#        Unnamed: 0  cyto.10p11.1  cyto.10p11.21  cyto.10p11.22  cyto.10p11.23  \
# count    20.00000     19.000000      20.000000      20.000000      19.000000
# mean     10.50000     -0.022842     -26.390633       0.059393       0.002291
# std       5.91608      0.128323     118.037415       0.223410       0.069978
# min       1.00000     -0.309000    -527.876000      -0.076143      -0.170200
# 25%       5.75000     -0.050667      -0.028758       0.005884      -0.028267
# 50%      10.50000      0.009667      -0.004200       0.019214       0.007400
# 75%      15.25000      0.052167       0.029042       0.027750       0.045333
# max      20.00000      0.154333       0.080800       1.000000       0.146733
#
#        cyto.10p12.1  cyto.10p12.2  cyto.10p12.31  cyto.10p12.32  \
# count     20.000000     20.000000      20.000000      19.000000
# mean       0.064460      0.066345      -8.755932      -0.014684
# std        0.222588      0.224195      39.198527       0.148045
# ...

# %%
plt.figure(figsize = (20,10))
for i in range(32) :
    K100.iloc[i,1:765].plot(color = 'b', alpha = 0.3) #bc
for i in range(32,53) :
    K100.iloc[i,1:765].plot(color = 'r', alpha = 0.3) #normal
for i in range(53,73) :
    K100.iloc[i,1:765].plot(color = 'y', alpha = 0.3) #rc
for i in range(73,94) :
    K100.iloc[i,1:765].plot(color = 'g', alpha = 0.3) #pc

# %%
K100.iloc[1,1:765].plot()

# %%
K100.loc[id]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [0] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-d9ed06ddb900> in <module>()
# ----> 1 K100.loc[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
# ...
